# %% [markdown]
# # Training "sophisticated" approach

# %% [markdown]
# ## Preparation

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
project_path = Path().resolve().parent
input_path = project_path / "results" / "intermediate" / "training" / "sophisticated"
#output_path = project_path / "results" / "MGE_files"

# %% [markdown]
# ## Joined performance

# %%
thresholds=pd.read_csv(project_path / "results" / "intermediate" / "training" / "sophisticated_thresholds.txt", header=None)
thresholds
for i in thresholds[0]:
    print(i)
# Out:
# 0.2 10 0.1 3
# 0.2 10 0.1 4
# 0.2 10 0.1 5
# 0.2 10 0.2 3
# 0.2 10 0.2 4
# 0.2 10 0.2 5
# 0.2 10 0.3 3
# 0.2 10 0.3 4
# 0.2 10 0.3 5
# 0.2 20 0.1 3
# 0.2 20 0.1 4
# 0.2 20 0.1 5
# 0.2 20 0.2 3
# 0.2 20 0.2 4
# 0.2 20 0.2 5
# 0.2 20 0.3 3
# 0.2 20 0.3 4
# 0.2 20 0.3 5
# 0.2 30 0.1 3
# 0.2 30 0.1 4
# 0.2 30 0.1 5
# 0.2 30 0.2 3
# 0.2 30 0.2 4
# 0.2 30 0.2 5
# 0.2 30 0.3 3
# 0.2 30 0.3 4
# 0.2 30 0.3 5
# 0.3 10 0.1 3
# 0.3 10 0.1 4
# 0.3 10 0.1 5
# 0.3 10 0.2 3
# 0.3 10 0.2 4
# 0.3 10 0.2 5
# 0.3 10 0.3 3
# 0.3 10 0.3 4
# 0.3 10 0.3 5
# 0.3 20 0.1 3
# 0.3 20 0.1 4
# 0.3 20 0.1 5
# 0.3 20 0.2 3
# 0.3 20 0.2 4
# 0.3 20 0.2 5
# 0.3 20 0.3 3
# 0.3 20 0.3 4
# 0.3 20 0.3 5
# 0.3 30 0.1 3
# 0.3 30 0.1 4
# 0.3 30 0.1 5
# 0.3 30 0.2 3
# 0.3 30 0.2 4
# 0.3 30 0.2 5
# 0.3 30 0.3 3
# 0.3 30 0.3 4
# 0.3 30 0.3 5
# 0.4 10 0.1 3
# 0.4 10 0.1 4
# 0.4 10 0.1 5
# 0.4 10 0.2 3
# 0.4 10 0.2 4
# 0.4 10 0.2 5
# 0.4 10 0.3 3
# 0.4 10 0.3 4
# 0.4 10 0.3 5
# 0.4 20 0.1 3
# 0.4 20 0.1 4
# 0.4 20 0.1 5
# 0.4 20 0.2 3
# 0.4 20 0.2 4
# 0.4 20 0.2 5
# 0.4 20 0.3 3
# 0.4 20 0.3 4
# 0.4 20 0.3 5
# 0.4 30 0.1 3
# 0.4 30 0.1 4
# 0.4 30 0.1 5
# 0.4 30 0.2 3
# 0.4 30 0.2 4
# 0.4 30 0.2 5
# 0.4 30 0.3 3
# 0.4 30 0.3 4
# 0.4 30 0.3 5

# %%
performance=pd.DataFrame(columns=['genome', 'score_threshold', 'n_threshold', 'fraction_threshold', 'n_scc_threshold', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator'])
#performance = pd.read_csv(input_path / str(i) / "joined_performance.csv", engine="python")
for i in thresholds[0]:
    perf = pd.read_csv(input_path / str(i) / "joined_performance.csv", engine="python", names=['genome', 'score_threshold', 'n_threshold', 'fraction_threshold', 'n_scc_threshold', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator'], header=None)
    performance=pd.concat([performance, perf])
performance['dispersion_weighted']=(performance.nr_toolscheme)*(pd.to_numeric(performance.avge_dispersion, errors='coerce'))
performance
# Out:
#              genome  score_threshold n_threshold  fraction_threshold  \
# 0   GCA_000820965.2              0.2          10                 0.1
# 1   GCA_000963335.1              0.2          10                 0.1
# 2   GCA_002860885.1              0.2          10                 0.1
# 3   GCA_001682765.1              0.2          10                 0.1
# 4   GCA_002289685.1              0.2          10                 0.1
# ..              ...              ...         ...                 ...
# 17  GCA_002945975.1              0.4          30                 0.3
# 18  GCA_004766225.1              0.4          30                 0.3
# 19  GCA_000229385.2              0.4          30                 0.3
# 20  GCA_001675535.1              0.4          30                 0.3
# 21  GCA_002138395.1              0.4          30                 0.3
#
#    n_scc_threshold nr_tool nr_toolscheme nr_scheme avge_dispersion  \
# 0                3       2             2        12             1.0
# 1                3       3             1        13             1.0
# 2                3       5             0        13             NaN
# 3                3       3             0         8             NaN
# 4                3       8             0         4             NaN
# ..             ...     ...           ...       ...             ...
# 17               5       5             0         0            None
# 18               5       3             0         0            None
# 19               5       0             0         0            None
# 20               5       1             0         0            None
# 21               5       5             0         0            None
#
#    coverage_denominator coverage_numerator dispersion_weighted
# 0                    38                 38                 2.0
# 1                    20                 13                 1.0
# 2                     0                  0                 NaN
# 3                     0                  0                 NaN
# 4                     0                  0                 NaN
# ..                  ...                ...                 ...
# 17                    0                  0                 NaN
# 18                    0                  0                 NaN
# 19                    0                  0                 NaN
# 20                    0                  0                 NaN
# 21                    0                  0                 NaN
#
# [2430 rows x 12 columns]

# %%
#perf_wide=performance.pivot(index='genome', columns='n_threshold', values=['nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator'])
#perf_wide

# %%
measures=performance.groupby(by=['score_threshold', 'n_threshold', 'fraction_threshold', 'n_scc_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
# Out:
#                                                                 precision  \
# score_threshold n_threshold fraction_threshold n_scc_threshold
# 0.2             10          0.1                3                 0.045828
#                                                4                 0.045991
#                                                5                 0.046099
#                             0.2                3                 0.042965
#                                                4                 0.043956
# ...                                                                   ...
# 0.4             30          0.2                4                 0.500000
#                                                5                 0.500000
#                             0.3                3                 0.588235
#                                                4                 0.526316
#                                                5                 0.526316
#
#                                                                   recall  \
# score_threshold n_threshold fraction_threshold n_scc_threshold
# 0.2             10          0.1                3                0.188406
#                                                4                0.188406
#                                                5                0.188406
#                             0.2                3                0.193237
#                                                4                0.193237
# ...                                                                  ...
# 0.4             30          0.2                4                0.100000
#                                                5                0.100000
#                             0.3                3                0.128205
#                                                4                0.128205
#                                                5                0.131579
#
#                                                                  F-score  \
# score_threshold n_threshold fraction_threshold n_scc_threshold
# 0.2             10          0.1                3                0.073724
#                                                4                0.073934
#                                                5                0.074074
#                             0.2                3                0.070299
#                                                4                0.071620
# ...                                                                  ...
# 0.4             30          0.2                4                0.166667
#                                                5                0.166667
#                             0.3                3                0.210526
#                                                4                0.206186
#                                                5                0.210526
#
#                                                                 dispersion  \
# score_threshold n_threshold fraction_threshold n_scc_threshold
# 0.2             10          0.1                3                  1.102564
#                                                4                  1.102564
#                                                5                  1.076923
#                             0.2                3                  1.075000
#                                                4                  1.075000
# ...                                                                    ...
# 0.4             30          0.2                4                  1.000000
#                                                5                  1.000000
#                             0.3                3                  1.000000
#                                                4                  1.000000
#                                                5                  1.000000
#
#                                                                 coverage
# score_threshold n_threshold fraction_threshold n_scc_threshold
# 0.2             10          0.1                3                0.781788
#                                                4                0.780148
#                                                5                0.769483
#                             0.2                3                0.752932
#                                                4                0.747459
# ...                                                                  ...
# 0.4             30          0.2                4                0.882698
#                                                5                0.882698
#                             0.3                3                0.838196
#                                                4                0.838196
#                                                5                0.838196
#
# [81 rows x 5 columns]
