# %% [markdown]
# # Benchmarking "baseline" approach

# %% [markdown]
# ## Preparation

# %%
149/50
# Out:
# 2.98

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
project_path = Path().resolve().parent
input_path = project_path / "results" / "intermediate" / "benchmarking" / "baseline" / "20"
#output_path = project_path / "results" / "MGE_files"

# %% [markdown]
# ## CONJscan

# %%
conjscan = pd.read_csv(input_path / "conjscan_performance.csv")
conjscan.columns=['genome', 'n_threshold', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
conjscan['dispersion_weighted']=(conjscan.nr_toolscheme)*(pd.to_numeric(conjscan.avge_dispersion, errors='coerce'))

conjscan
# Out:
#              genome  n_threshold  nr_tool  nr_toolscheme  nr_scheme  \
# 0   GCA_001868825.1           20        0              0          2
# 1   GCA_002017995.1           20        7              2         12
# 2   GCA_002092085.1           20        0              0          2
# 3   GCA_000504125.1           20        5              0         10
# 4   GCA_900116975.1           20        0              0          6
# 5   GCA_001073005.1           20        0              0          0
# 6   GCA_004361545.1           20        0              0         11
# 7   GCA_002077495.1           20        1              1          8
# 8   GCA_000309605.1           20        0              0         11
# 9   GCA_001649985.1           20        0              0          5
# 10  GCA_003796045.1           20        0              0          4
# 11  GCA_001815805.1           20        0              0          2
# 12  GCA_900992665.1           20        0              0          5
# 13  GCA_003963555.1           20        1              1          5
# 14  GCA_000441015.1           20       12              2          6
# 15  GCA_000232205.2           20        0              0          6
# 16  GCA_004055405.1           20        0              0          6
# 17  GCA_901544225.1           20        3              3          9
# 18  GCA_000465735.1           20        0              0          3
# 19  GCA_900490745.1           20        0              0          4
# 20  GCA_002532085.1           20        0              0          3
# 21  GCA_004334905.1           20        0              0          4
# 22  GCA_003606705.1           20        0              0          1
# 23  GCA_001304545.1           20        0              0          3
# 24  GCA_002083175.2           20        1              1          2
# 25  GCA_001578785.1           20        0              0          0
# 26  GCA_002897535.1           20        0              0          2
# 27  GCA_001334315.1           20        2              1          3
# 28  GCA_000522565.1           20        0              0          2
# 29  GCA_000339895.1           20        0              0          0
# 30  GCA_002165725.1           20        0              0          8
# 31  GCA_003606735.1           20        1              1          4
# 32  GCA_003712425.1           20        0              0          7
# 33  GCA_000441235.1           20        6              2          5
# 34  GCA_003859585.1           20        3              1          3
# 35  GCA_002073835.2           20        1              1          3
# 36  GCA_002269965.1           20        0              0          4
# 37  GCA_900475695.1           20        1              1          4
# 38  GCA_901543075.1           20        2              1          6
# 39  GCA_901542375.1           20        0              0          2
# 40  GCA_007096405.1           20        3              1          5
# 41  GCA_002213365.1           20        1              0          3
# 42  GCA_900100215.1           20        0              0          1
# 43  GCA_002525085.1           20        0              0          2
# 44  GCA_001097865.1           20        2              1          2
# 45  GCA_001760805.1           20        0              0          1
# 46  GCA_000813025.1           20        0              0          1
# 47  GCA_902159345.1           20        2              0          4
# 48  GCA_006381655.1           20        1              0          5
# 49  GCA_003942485.1           20        1              1          1
#
#    avge_dispersion  coverage_denominator  coverage_numerator  \
# 0             None                     0                   0
# 1              1.0                    28                  24
# 2             None                     0                   0
# 3              NaN                     0                   0
# 4             None                     0                   0
# 5             None                     0                   0
# 6             None                     0                   0
# 7              1.0                    10                  10
# 8             None                     0                   0
# 9             None                     0                   0
# 10            None                     0                   0
# 11            None                     0                   0
# 12            None                     0                   0
# 13             1.0                    10                   7
# 14             1.0                    34                   9
# 15            None                     0                   0
# 16            None                     0                   0
# 17             1.0                    35                  10
# 18            None                     0                   0
# 19            None                     0                   0
# 20            None                     0                   0
# 21            None                     0                   0
# 22            None                     0                   0
# 23            None                     0                   0
# 24             1.0                    11                  11
# 25            None                     0                   0
# 26            None                     0                   0
# 27             1.0                     9                   6
# 28            None                     0                   0
# 29            None                     0                   0
# 30            None                     0                   0
# 31             1.0                    10                  10
# 32            None                     0                   0
# 33             1.0                    22                  19
# 34             1.0                     8                   7
# 35             1.0                    10                   7
# 36            None                     0                   0
# 37             1.0                    15                  11
# 38             1.0                     8                   1
# 39            None                     0                   0
# 40             1.0                     6                   6
# 41             NaN                     0                   0
# 42            None                     0                   0
# 43            None                     0                   0
# 44             1.0                     7                   7
# 45            None                     0                   0
# 46            None                     0                   0
# 47             NaN                     0                   0
# 48             NaN                     0                   0
# 49             1.0                     7                   6
#
#     dispersion_weighted
# 0                   NaN
# 1                   2.0
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   1.0
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  1.0
# 14                  2.0
# 15                  NaN
# 16                  NaN
# 17                  3.0
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  1.0
# 25                  NaN
# 26                  NaN
# 27                  1.0
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  1.0
# 32                  NaN
# 33                  2.0
# 34                  1.0
# 35                  1.0
# 36                  NaN
# 37                  1.0
# 38                  1.0
# 39                  NaN
# 40                  1.0
# 41                  NaN
# 42                  NaN
# 43                  NaN
# 44                  1.0
# 45                  NaN
# 46                  NaN
# 47                  NaN
# 48                  NaN
# 49                  1.0

# %%
measures=conjscan.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 20                56             21        208                   230
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 20                          21.0                 151

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision  recall   F-score  dispersion  coverage
# 0           20   0.100962   0.375  0.159091         1.0  0.656522

# %% [markdown]
# ## Phaster

# %%
phaster = pd.read_csv(input_path / "phaster_performance.csv")
phaster.columns=['genome', 'n_threshold', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
phaster['dispersion_weighted']=(phaster.nr_toolscheme)*(pd.to_numeric(phaster.avge_dispersion, errors='coerce'))

phaster
# Out:
#              genome  n_threshold  nr_tool  nr_toolscheme  nr_scheme  \
# 0   GCA_001868825.1           20        3              0          2
# 1   GCA_002017995.1           20       13             12         12
# 2   GCA_002092085.1           20        4              2          2
# 3   GCA_000504125.1           20        5              4         10
# 4   GCA_900116975.1           20        9              4          6
# 5   GCA_001073005.1           20        2              0          0
# 6   GCA_004361545.1           20        4              4         11
# 7   GCA_002077495.1           20        2              2          8
# 8   GCA_000309605.1           20        9              6         11
# 9   GCA_001649985.1           20        4              0          5
# 10  GCA_003796045.1           20        2              1          4
# 11  GCA_001815805.1           20        1              0          2
# 12  GCA_900992665.1           20        4              3          5
# 13  GCA_003963555.1           20        3              2          5
# 14  GCA_000441015.1           20        4              4          6
# 15  GCA_000232205.2           20        6              4          6
# 16  GCA_004055405.1           20        5              4          6
# 17  GCA_901544225.1           20        7              5          9
# 18  GCA_000465735.1           20        3              1          3
# 19  GCA_900490745.1           20        2              2          4
# 20  GCA_002532085.1           20        0              0          3
# 21  GCA_004334905.1           20        4              2          4
# 22  GCA_003606705.1           20        5              0          1
# 23  GCA_001304545.1           20        3              2          3
# 24  GCA_002083175.2           20        2              2          2
# 25  GCA_001578785.1           20        4              0          0
# 26  GCA_002897535.1           20        2              0          2
# 27  GCA_001334315.1           20        2              1          3
# 28  GCA_000522565.1           20        3              2          2
# 29  GCA_000339895.1           20        2              0          0
# 30  GCA_002165725.1           20        3              2          8
# 31  GCA_003606735.1           20        1              0          4
# 32  GCA_003712425.1           20        7              4          7
# 33  GCA_000441235.1           20        3              1          5
# 34  GCA_003859585.1           20        1              0          3
# 35  GCA_002073835.2           20        1              1          3
# 36  GCA_002269965.1           20        5              4          4
# 37  GCA_900475695.1           20        3              2          4
# 38  GCA_901543075.1           20        2              2          6
# 39  GCA_901542375.1           20        1              1          2
# 40  GCA_007096405.1           20        5              4          5
# 41  GCA_002213365.1           20        3              1          3
# 42  GCA_900100215.1           20        1              0          1
# 43  GCA_002525085.1           20        3              2          2
# 44  GCA_001097865.1           20        1              0          2
# 45  GCA_001760805.1           20        2              0          1
# 46  GCA_000813025.1           20        1              0          1
# 47  GCA_902159345.1           20        3              2          4
# 48  GCA_006381655.1           20        2              1          5
# 49  GCA_003942485.1           20        1              0          1
#
#    avge_dispersion  coverage_denominator  coverage_numerator  \
# 0              NaN                     0                   0
# 1              1.0                   201                 201
# 2              1.0                    79                  63
# 3              1.0                   186                 170
# 4              1.0                   156                 156
# 5             None                     0                   0
# 6              1.0                   173                 164
# 7              1.0                   102                 101
# 8              1.0                   177                 164
# 9              NaN                     0                   0
# 10             1.0                    52                  48
# 11             NaN                     0                   0
# 12             1.0                   159                 138
# 13             1.0                    76                  68
# 14             1.0                   173                 134
# 15             1.0                    92                  81
# 16             1.0                   110                 107
# 17             1.0                   217                 180
# 18             1.0                    75                  75
# 19             1.0                    97                  76
# 20            None                     0                   0
# 21             1.0                    69                  69
# 22             NaN                     0                   0
# 23             1.0                    49                  47
# 24             1.0                    63                  61
# 25            None                     0                   0
# 26             NaN                     0                   0
# 27             1.0                    63                  62
# 28             1.0                    17                  17
# 29            None                     0                   0
# 30             1.5                   137                 131
# 31             NaN                     0                   0
# 32             1.0                   139                 125
# 33             1.0                    68                  56
# 34             NaN                     0                   0
# 35             1.0                   112                 101
# 36             1.0                   200                 185
# 37             1.0                    79                  71
# 38             1.0                    57                  55
# 39             1.0                    38                  24
# 40             1.0                   152                 131
# 41             1.0                    51                  31
# 42             NaN                     0                   0
# 43             1.0                   107                  92
# 44             NaN                     0                   0
# 45             NaN                     0                   0
# 46             NaN                     0                   0
# 47             1.0                    98                  98
# 48             1.0                    57                  49
# 49             NaN                     0                   0
#
#     dispersion_weighted
# 0                   NaN
# 1                  12.0
# 2                   2.0
# 3                   4.0
# 4                   4.0
# 5                   NaN
# 6                   4.0
# 7                   2.0
# 8                   6.0
# 9                   NaN
# 10                  1.0
# 11                  NaN
# 12                  3.0
# 13                  2.0
# 14                  4.0
# 15                  4.0
# 16                  4.0
# 17                  5.0
# 18                  1.0
# 19                  2.0
# 20                  NaN
# 21                  2.0
# 22                  NaN
# 23                  2.0
# 24                  2.0
# 25                  NaN
# 26                  NaN
# 27                  1.0
# 28                  2.0
# 29                  NaN
# 30                  3.0
# 31                  NaN
# 32                  4.0
# 33                  1.0
# 34                  NaN
# 35                  1.0
# 36                  4.0
# 37                  2.0
# 38                  2.0
# 39                  1.0
# 40                  4.0
# 41                  1.0
# 42                  NaN
# 43                  2.0
# 44                  NaN
# 45                  NaN
# 46                  NaN
# 47                  2.0
# 48                  1.0
# 49                  NaN

# %%
measures=phaster.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 20               168             96        208                  3681
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 20                          97.0                3331

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision    recall   F-score  dispersion  coverage
# 0           20   0.461538  0.571429  0.510638    1.010417  0.904917

# %% [markdown]
# ## Joined for recall and precision

# %%
joined = pd.read_csv(input_path / "joined_performance.csv")
joined.columns=['genome', 'n_threshold', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
joined['dispersion_weighted']=(joined.nr_toolscheme)*(pd.to_numeric(joined.avge_dispersion, errors='coerce'))

joined
# Out:
#              genome  n_threshold  nr_tool  nr_toolscheme  nr_scheme  \
# 0   GCA_001868825.1           20        3              0          2
# 1   GCA_002017995.1           20       20             14         12
# 2   GCA_002092085.1           20        4              2          2
# 3   GCA_000504125.1           20       10              4         10
# 4   GCA_900116975.1           20        9              4          6
# 5   GCA_001073005.1           20        2              0          0
# 6   GCA_004361545.1           20        4              4         11
# 7   GCA_002077495.1           20        3              3          8
# 8   GCA_000309605.1           20        9              6         11
# 9   GCA_001649985.1           20        4              0          5
# 10  GCA_003796045.1           20        2              1          4
# 11  GCA_001815805.1           20        1              0          2
# 12  GCA_900992665.1           20        4              3          5
# 13  GCA_003963555.1           20        4              3          5
# 14  GCA_000441015.1           20       15              5          6
# 15  GCA_000232205.2           20        6              4          6
# 16  GCA_004055405.1           20        5              4          6
# 17  GCA_901544225.1           20       10              8          9
# 18  GCA_000465735.1           20        3              1          3
# 19  GCA_900490745.1           20        2              2          4
# 20  GCA_002532085.1           20        0              0          3
# 21  GCA_004334905.1           20        4              2          4
# 22  GCA_003606705.1           20        5              0          1
# 23  GCA_001304545.1           20        3              2          3
# 24  GCA_002083175.2           20        3              3          2
# 25  GCA_001578785.1           20        4              0          0
# 26  GCA_002897535.1           20        2              0          2
# 27  GCA_001334315.1           20        4              2          3
# 28  GCA_000522565.1           20        3              2          2
# 29  GCA_000339895.1           20        2              0          0
# 30  GCA_002165725.1           20        3              2          8
# 31  GCA_003606735.1           20        2              1          4
# 32  GCA_003712425.1           20        7              4          7
# 33  GCA_000441235.1           20        9              3          5
# 34  GCA_003859585.1           20        4              1          3
# 35  GCA_002073835.2           20        2              2          3
# 36  GCA_002269965.1           20        5              4          4
# 37  GCA_900475695.1           20        4              3          4
# 38  GCA_901543075.1           20        4              3          6
# 39  GCA_901542375.1           20        1              1          2
# 40  GCA_007096405.1           20        8              5          5
# 41  GCA_002213365.1           20        4              1          3
# 42  GCA_900100215.1           20        1              0          1
# 43  GCA_002525085.1           20        3              2          2
# 44  GCA_001097865.1           20        3              1          2
# 45  GCA_001760805.1           20        2              0          1
# 46  GCA_000813025.1           20        1              0          1
# 47  GCA_902159345.1           20        5              2          4
# 48  GCA_006381655.1           20        3              1          5
# 49  GCA_003942485.1           20        2              1          1
#
#    avge_dispersion  coverage_denominator  coverage_numerator  \
# 0              NaN                     0                   0
# 1              1.0                   229                 225
# 2              1.0                    79                  63
# 3              1.0                   186                 170
# 4              1.0                   156                 156
# 5             None                     0                   0
# 6              1.0                   173                 164
# 7              1.0                   112                 111
# 8              1.0                   177                 164
# 9              NaN                     0                   0
# 10             1.0                    52                  48
# 11             NaN                     0                   0
# 12             1.0                   159                 138
# 13             1.0                    86                  75
# 14             1.0                   179                 140
# 15             1.0                    92                  81
# 16             1.0                   110                 107
# 17             1.0                   252                 190
# 18             1.0                    75                  75
# 19             1.0                    97                  76
# 20            None                     0                   0
# 21             1.0                    69                  69
# 22             NaN                     0                   0
# 23             1.0                    49                  47
# 24             1.0                    69                  67
# 25            None                     0                   0
# 26             NaN                     0                   0
# 27             1.0                    72                  68
# 28             1.0                    17                  17
# 29            None                     0                   0
# 30             1.5                   137                 131
# 31             1.0                    10                  10
# 32             1.0                   139                 125
# 33             1.0                    90                  75
# 34             1.0                     8                   7
# 35             1.0                   122                 108
# 36             1.0                   200                 185
# 37             1.0                    94                  82
# 38             1.0                    65                  56
# 39             1.0                    38                  24
# 40             1.0                   158                 137
# 41             1.0                    51                  31
# 42             NaN                     0                   0
# 43             1.0                   107                  92
# 44             1.0                     7                   7
# 45             NaN                     0                   0
# 46             NaN                     0                   0
# 47             1.0                    98                  98
# 48             1.0                    57                  49
# 49             1.0                     7                   6
#
#     dispersion_weighted
# 0                   NaN
# 1                  14.0
# 2                   2.0
# 3                   4.0
# 4                   4.0
# 5                   NaN
# 6                   4.0
# 7                   3.0
# 8                   6.0
# 9                   NaN
# 10                  1.0
# 11                  NaN
# 12                  3.0
# 13                  3.0
# 14                  5.0
# 15                  4.0
# 16                  4.0
# 17                  8.0
# 18                  1.0
# 19                  2.0
# 20                  NaN
# 21                  2.0
# 22                  NaN
# 23                  2.0
# 24                  3.0
# 25                  NaN
# 26                  NaN
# 27                  2.0
# 28                  2.0
# 29                  NaN
# 30                  3.0
# 31                  1.0
# 32                  4.0
# 33                  3.0
# 34                  1.0
# 35                  2.0
# 36                  4.0
# 37                  3.0
# 38                  3.0
# 39                  1.0
# 40                  5.0
# 41                  1.0
# 42                  NaN
# 43                  2.0
# 44                  1.0
# 45                  NaN
# 46                  NaN
# 47                  2.0
# 48                  1.0
# 49                  1.0

# %%
measures=joined.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 20               223            116        208                  3878
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 20                         117.0                3474

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision    recall   F-score  dispersion  coverage
# 0           20   0.557692  0.520179  0.538283    1.008621  0.895823

# %% [markdown]
# # Benchmarking "simple" approach

# %% [markdown]
# ## Preparation

# %%
project_path = Path().resolve().parent
input_path = project_path / "results" / "intermediate" / "benchmarking" / "simple" / "0.4 20"
#output_path = project_path / "results" / "MGE_files"

# %% [markdown]
# ## CONJscan

# %%
conjscan = pd.read_csv(input_path / "conjscan_performance.csv")
conjscan.columns=['genome', 'n_threshold', 'score_threshold', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numer
# 18          3            None                     0                   0
# 19          2            None                     0                   0
# 20          0            None                     0                   0
# 21          2            None                     0                   0
# 22          1            None                     0                   0
# 23          2            None                     0                   0
# 24          2             1.0                    11                  11
# 25          0            None                     0                   0
# 26          0            None                     0                   0
# 27          3             1.0                     9                   6
# 28          0            None                     0                   0
# 29          0            None                     0                   0
# 30          3            None                     0                   0
# 31          1             1.0                    10                  10
# 32          3            None                     0                   0
# 33          5             1.0                    22                  20
# 34          3             1.0                     8                   2
# 35          3             NaN                     0                   0
# 36          6            None                     0                   0
# 37          3             1.0                    15                   7
# 38          5             1.0                     8                   1
# 39          1            None                     0                   0
# 40          3             1.0                     6                   3
# 41          2             NaN                     0                   0
# 42          0            None                     0                   0
# 43          2            None                     0                   0
# 44          2             1.0                    18                  18
# 45          1            None                     0                   0
# 46          0            None                     0                   0
# 47          2             NaN                     0                   0
# 48          3             NaN                     0                   0
# 49          1             1.0                     7                   6
#
#     dispersion_weighted
# 0                   NaN
# 1                   2.0
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   1.0
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  1.0
# 14                  2.0
# 15                  NaN
# 16                  NaN
# 17                  1.0
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  1.0
# 25                  NaN
# 26                  NaN
# 27                  1.0
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  1.0
# 32                  NaN
# 33                  2.0
# 34                  1.0
# 35                  NaN
# 36                  NaN
# 37                  1.0
# 38                  1.0
# 39                  NaN
# 40                  1.0
# 41                  NaN
# 42                  NaN
# 43                  NaN
# 44                  2.0
# 45                  NaN
# 46                  NaN
# 47                  NaN
# 48                  NaN
# 49                  1.0

# %%
measures=conjscan.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 0.4               56             19        130                   203
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 0.4                         19.0                 123

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision    recall   F-score  dispersion  coverage
# 0          0.4   0.146154  0.339286  0.204301         1.0  0.605911

# %% [markdown]
# ## Phaster

# %%
phaster = pd.read_csv(input_path / "phaster_performance.csv")
phaster.columns=['genome', 'n_threshold', 'score_threshold', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
phaster['dispersion_weighted']=(phaster.nr_toolscheme)*(pd.to_numeric(phaster.avge_dispersion, errors='coerce'))

phaster
# Out:
#              genome  n_threshold  score_threshold  nr_tool  nr_toolscheme  \
# 0   GCA_001868825.1          0.4               20        3              0
# 1   GCA_002017995.1          0.4               20       13              2
# 2   GCA_002092085.1          0.4               20        4              1
# 3   GCA_000504125.1          0.4               20        5              4
# 4   GCA_900116975.1          0.4               20        9              3
# 5   GCA_001073005.1          0.4               20        2              0
# 6   GCA_004361545.1          0.4               20        4              4
# 7   GCA_002077495.1          0.4               20        2              2
# 8   GCA_000309605.1          0.4               20        9              7
# 9   GCA_001649985.1          0.4               20        4              0
# 10  GCA_003796045.1          0.4               20        2              1
# 11  GCA_001815805.1          0.4               20        1              0
# 12  GCA_900992665.1          0.4               20        4              3
# 13  GCA_003963555.1          0.4               20        3              1
# 14  GCA_000441015.1          0.4               20        4              3
# 15  GCA_000232205.2          0.4               20        6              2
# 16  GCA_004055405.1          0.4               20        5              2
# 17  GCA_901544225.1          0.4               20        7              4
# 18  GCA_000465735.1          0.4               20        3              1
# 19  GCA_900490745.1          0.4               20        2              2
# 20  GCA_002532085.1          0.4               20        0              0
# 21  GCA_004334905.1          0.4               20        4              2
# 22  GCA_003606705.1          0.4               20        5              0
# 23  GCA_001304545.1          0.4               20        3              1
# 24  GCA_002083175.2          0.4               20        2              2
# 25  GCA_001578785.1          0.4               20        4              0
# 26  GCA_002897535.1          0.4               20        2              0
# 27  GCA_001334315.1          0.4               20        2              1
# 28  GCA_000522565.1          0.4               20        3              0
# 29  GCA_000339895.1          0.4               20        2              0
# 30  GCA_002165725.1          0.4               20        3              2
# 31  GCA_003606735.1          0.4               20        1              0
# 32  GCA_003712425.1          0.4               20        7              3
# 33  GCA_000441235.1          0.4               20        3              1
# 34  GCA_003859585.1          0.4               20        1              0
# 35  GCA_002073835.2          0.4               20        1              1
# 36  GCA_002269965.1          0.4               20        5              3
# 37  GCA_900475695.1          0.4               20        3              2
# 38  GCA_901543075.1          0.4               20        2              1
# 39  GCA_901542375.1          0.4               20        1              1
# 40  GCA_007096405.1          0.4               20        5              2
# 41  GCA_002213365.1          0.4               20        3              1
# 42  GCA_900100215.1          0.4               20        1              0
# 43  GCA_002525085.1          0.4               20        3              2
# 44  GCA_001097865.1          0.4               20        1              0
# 45  GCA_001760805.1          0.4               20        2              0
# 46  GCA_000813025.1          0.4               20        1              0
# 47  GCA_902159345.1          0.4               20        3              2
# 48  GCA_006381655.1          0.4               20        2              1
# 49  GCA_003942485.1          0.4               20        1              0
#
#     nr_scheme     avge_dispersion  coverage_denominator  coverage_numerator  \
# 0           0                None                     0                   0
# 1           4                 1.0                    26                  22
# 2           1                 1.0                    63                  18
# 3          10                1.75                   186                 153
# 4           3                 1.0                   144                  91
# 5           0                None                     0                   0
# 6           5                 1.0                   173                 137
# 7           4                 1.5                   102                  86
# 8           8                 1.0                   211                 160
# 9           1                 NaN                     0                   0
# 10          2                 2.0                    52                  50
# 11          1                 NaN                     0                   0
# 12          5  1.3333333333333333                   159                 113
# 13          3                 1.0                    49                  40
# 14          5  1.3333333333333333                   131                 104
# 15          2                 1.0                    60                  52
# 16          3                 1.0                    85                  65
# 17          9                 1.5                   198                 176
# 18          3                 2.0                    75                  68
# 19          2                 1.0                    97                  47
# 20          0                None                     0                   0
# 21          2                 1.0                    69                  69
# 22          1                 NaN                     0                   0
# 23          2                 1.0                    22                  22
# 24          2                 1.0                    63                  54
# 25          0                None                     0                   0
# 26          0                None                     0                   0
# 27          3                 2.0                    63                  48
# 28          0                None                     0                   0
# 29          0                None                     0                   0
# 30          3                 1.5                   137                 130
# 31          1                 NaN                     0                   0
# 32          3                 1.0                   118                  78
# 33          5                 2.0                    68                  67
# 34          3                 NaN                     0                   0
# 35          3                 2.0                   112                  58
# 36          6                 2.0                   185                 161
# 37          3                 1.0                    79                  50
# 38          5                 1.0                    26                  24
# 39          1                 1.0                    38                  20
# 40          3                 1.0                    91                  44
# 41          2                 1.0                    51                  28
# 42          0                None                     0                   0
# 43          2                 1.0                   107                  47
# 44          2                 NaN                     0                   0
# 45          1                 NaN                     0                   0
# 46          0                None                     0                   0
# 47          2                 1.0                    98                  83
# 48          3                 1.0                    57                  26
# 49          1                 NaN                     0                   0
#
#     dispersion_weighted
# 0                   NaN
# 1                   2.0
# 2                   1.0
# 3                   7.0
# 4                   3.0
# 5                   NaN
# 6                   4.0
# 7                   3.0
# 8                   7.0
# 9                   NaN
# 10                  2.0
# 11                  NaN
# 12                  4.0
# 13                  1.0
# 14                  4.0
# 15                  2.0
# 16                  2.0
# 17                  6.0
# 18                  2.0
# 19                  2.0
# 20                  NaN
# 21                  2.0
# 22                  NaN
# 23                  1.0
# 24                  2.0
# 25                  NaN
# 26                  NaN
# 27                  2.0
# 28                  NaN
# 29                  NaN
# 30                  3.0
# 31                  NaN
# 32                  3.0
# 33                  2.0
# 34                  NaN
# 35                  2.0
# 36                  6.0
# 37                  2.0
# 38                  1.0
# 39                  1.0
# 40                  2.0
# 41                  1.0
# 42                  NaN
# 43                  2.0
# 44                  NaN
# 45                  NaN
# 46                  NaN
# 47                  2.0
# 48                  1.0
# 49                  NaN

# %%
measures=phaster.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 0.4              168             70        130                  3195
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 0.4                         87.0                2391

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision    recall   F-score  dispersion  coverage
# 0          0.4   0.538462  0.416667  0.469799    1.242857  0.748357

# %% [markdown]
# ## Joined for recall and precision

# %%
joined = pd.read_csv(input_path / "joined_performance.csv")
joined.columns=['genome', 'n_threshold', 'score_threshold',  'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
joined['dispersion_weighted']=(joined.nr_toolscheme)*(pd.to_numeric(joined.avge_dispersion, errors='coerce'))

joined
# Out:
#              genome  n_threshold  score_threshold  nr_tool  nr_toolscheme  \
# 0   GCA_001868825.1          0.4               20        3              0
# 1   GCA_002017995.1          0.4               20       20              4
# 2   GCA_002092085.1          0.4               20        4              1
# 3   GCA_000504125.1          0.4               20       10              4
# 4   GCA_900116975.1          0.4               20        9              3
# 5   GCA_001073005.1          0.4               20        2              0
# 6   GCA_004361545.1          0.4               20        4              4
# 7   GCA_002077495.1          0.4               20        3              3
# 8   GCA_000309605.1          0.4               20        9              7
# 9   GCA_001649985.1          0.4               20        4              0
# 10  GCA_003796045.1          0.4               20        2              1
# 11  GCA_001815805.1          0.4               20        1              0
# 12  GCA_900992665.1          0.4               20        4              3
# 13  GCA_003963555.1          0.4               20        4              2
# 14  GCA_000441015.1          0.4               20       15              4
# 15  GCA_000232205.2          0.4               20        6              2
# 16  GCA_004055405.1          0.4               20        5              2
# 17  GCA_901544225.1          0.4               20       10              5
# 18  GCA_000465735.1          0.4               20        3              1
# 19  GCA_900490745.1          0.4               20        2              2
# 20  GCA_002532085.1          0.4               20        0              0
# 21  GCA_004334905.1          0.4               20        4              2
# 22  GCA_003606705.1          0.4               20        5              0
# 23  GCA_001304545.1          0.4               20        3              1
# 24  GCA_002083175.2          0.4               20        3              3
# 25  GCA_001578785.1          0.4               20        4              0
# 26  GCA_002897535.1          0.4               20        2              0
# 27  GCA_001334315.1          0.4               20        4              2
# 28  GCA_000522565.1          0.4               20        3              0
# 29  GCA_000339895.1          0.4               20        2              0
# 30  GCA_002165725.1          0.4               20        3              2
# 31  GCA_003606735.1          0.4               20        2              1
# 32  GCA_003712425.1          0.4               20        7              3
# 33  GCA_000441235.1          0.4               20        9              3
# 34  GCA_003859585.1          0.4               20        4              1
# 35  GCA_002073835.2          0.4               20        2              1
# 36  GCA_002269965.1          0.4               20        5              3
# 37  GCA_900475695.1          0.4               20        4              3
# 38  GCA_901543075.1          0.4               20        4              2
# 39  GCA_901542375.1          0.4               20        1              1
# 40  GCA_007096405.1          0.4               20        8              3
# 41  GCA_002213365.1          0.4               20        4              1
# 42  GCA_900100215.1          0.4               20        1              0
# 43  GCA_002525085.1          0.4               20        3              2
# 44  GCA_001097865.1          0.4               20        3              2
# 45  GCA_001760805.1          0.4               20        2              0
# 46  GCA_000813025.1          0.4               20        1              0
# 47  GCA_902159345.1          0.4               20        5              2
# 48  GCA_006381655.1          0.4               20        3              1
# 49  GCA_003942485.1          0.4               20        2              1
#
#     nr_scheme     avge_dispersion  coverage_denominator  coverage_numerator  \
# 0           0                None                     0                   0
# 1           4                 1.0                    54                  34
# 2           1                 1.0                    63                  18
# 3          10                1.75                   186                 153
# 4           3                 1.0                   144                  91
# 5           0                None                     0                   0
# 6           5                 1.0                   173                 137
# 7           4  1.3333333333333333                   112                  96
# 8           8                 1.0                   211                 160
# 9           1                 NaN                     0                   0
# 10          2                 2.0                    52                  50
# 11          1                 NaN                     0                   0
# 12          5  1.3333333333333333                   159                 113
# 13          3                 1.0                    59                  47
# 14          5                1.25                   137                 110
# 15          2                 1.0                    60                  52
# 16          3                 1.0                    85                  65
# 17          9                 1.4                   205                 177
# 18          3                 2.0                    75                  68
# 19          2                 1.0                    97                  47
# 20          0                None                     0                   0
# 21          2                 1.0                    69                  69
# 22          1                 NaN                     0                   0
# 23          2                 1.0                    22                  22
# 24          2                 1.0                    69                  60
# 25          0                None                     0                   0
# 26          0                None                     0                   0
# 27          3                 1.5                    72                  54
# 28          0                None                     0                   0
# 29          0                None                     0                   0
# 30          3                 1.5                   137                 130
# 31          1                 1.0                    10                  10
# 32          3                 1.0                   118                  78
# 33          5  1.3333333333333333                    90                  87
# 34          3                 1.0                     8                   2
# 35          3                 2.0                   112                  58
# 36          6                 2.0                   185                 161
# 37          3                 1.0                    94                  57
# 38          5                 1.0                    34                  25
# 39          1                 1.0                    38                  20
# 40          3                 1.0                    97                  47
# 41          2                 1.0                    51                  28
# 42          0                None                     0                   0
# 43          2                 1.0                   107                  47
# 44          2                 1.0                    18                  18
# 45          1                 NaN                     0                   0
# 46          0                None                     0                   0
# 47          2                 1.0                    98                  83
# 48          3                 1.0                    57                  26
# 49          1                 1.0                     7                   6
#
#     dispersion_weighted
# 0                   NaN
# 1                   4.0
# 2                   1.0
# 3                   7.0
# 4                   3.0
# 5                   NaN
# 6                   4.0
# 7                   4.0
# 8                   7.0
# 9                   NaN
# 10                  2.0
# 11                  NaN
# 12                  4.0
# 13                  2.0
# 14                  5.0
# 15                  2.0
# 16                  2.0
# 17                  7.0
# 18                  2.0
# 19                  2.0
# 20                  NaN
# 21                  2.0
# 22                  NaN
# 23                  1.0
# 24                  3.0
# 25                  NaN
# 26                  NaN
# 27                  3.0
# 28                  NaN
# 29                  NaN
# 30                  3.0
# 31                  1.0
# 32                  3.0
# 33                  4.0
# 34                  1.0
# 35                  2.0
# 36                  6.0
# 37                  3.0
# 38                  2.0
# 39                  1.0
# 40                  3.0
# 41                  1.0
# 42                  NaN
# 43                  2.0
# 44                  2.0
# 45                  NaN
# 46                  NaN
# 47                  2.0
# 48                  1.0
# 49                  1.0

# %%
measures=joined.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 0.4              223             88        130                  3365
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 0.4                        105.0                2506

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision    recall   F-score  dispersion  coverage
# 0          0.4   0.676923  0.394619  0.498584    1.193182  0.744725

# %% [markdown]
# # Benchmarking "intermediate" approach

# %% [markdown]
# ## Preparation

# %%
project_path = Path().resolve().parent
input_path = project_path / "results" / "intermediate" / "benchmarking" / "intermediate" / "0.4 20 5 5"
#output_path = project_path / "results" / "MGE_files"

# %% [markdown]
# ## CONJscan

# %%
conjscan = pd.read_csv(input_path / "conjscan_performance.csv")
conjscan.columns=['genome', 'n_threshold', 'score_threshold', 'initialsize', 'distance', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
conjscan['dispersion_weighted']=(conjscan.nr_toolscheme)*(pd.to_numeric(conjscan.avge_dispersion, errors='coerce'))

conjscan
# Out:
#              genome  n_threshold  score_threshold  initialsize  distance  \
# 0   GCA_001868825.1          0.4               20            5         5
# 1   GCA_002017995.1          0.4               20            5         5
# 2   GCA_002092085.1          0.4               20            5         5
# 3   GCA_000504125.1          0.4               20            5         5
# 4   GCA_900116975.1          0.4               20            5         5
# 5   GCA_001073005.1          0.4               20            5         5
# 6   GCA_004361545.1          0.4               20            5         5
# 7   GCA_002077495.1          0.4               20            5         5
# 8   GCA_000309605.1          0.4               20            5         5
# 9   GCA_001649985.1          0.4               20            5         5
# 10  GCA_003796045.1          0.4               20            5         5
# 11  GCA_001815805.1          0.4               20            5         5
# 12  GCA_900992665.1          0.4               20            5         5
# 13  GCA_003963555.1          0.4               20            5         5
# 14  GCA_000441015.1          0.4               20            5         5
# 15  GCA_000232205.2          0.4               20            5         5
# 16  GCA_004055405.1          0.4               20            5         5
# 17  GCA_901544225.1          0.4               20            5         5
# 18  GCA_000465735.1          0.4               20            5         5
# 19  GCA_900490745.1          0.4               20            5         5
# 20  GCA_002532085.1          0.4               20            5         5
# 21  GCA_004334905.1          0.4               20            5         5
# 22  GCA_003606705.1          0.4               20            5         5
# 23  GCA_001304545.1          0.4               20            5         5
# 24  GCA_002083175.2          0.4               20            5         5
# 25  GCA_001578785.1          0.4               20            5         5
# 26  GCA_002897535.1          0.4               20            5         5
# 27  GCA_001334315.1          0.4               20            5         5
# 28  GCA_000522565.1          0.4               20            5         5
# 29  GCA_000339895.1          0.4               20            5         5
# 30  GCA_002165725.1          0.4               20            5         5
# 31  GCA_003606735.1          0.4               20            5         5
# 32  GCA_003712425.1          0.4               20            5         5
# 33  GCA_000441235.1          0.4               20            5         5
# 34  GCA_003859585.1          0.4               20            5         5
# 35  GCA_002073835.2          0.4               20            5         5
# 36  GCA_002269965.1          0.4               20            5         5
# 37  GCA_900475695.1          0.4               20            5         5
# 38  GCA_901543075.1          0.4               20            5         5
# 39  GCA_901542375.1          0.4               20            5         5
# 40  GCA_007096405.1          0.4               20            5         5
# 41  GCA_002213365.1          0.4               20            5         5
# 42  GCA_900100215.1          0.4               20            5         5
# 43  GCA_002525085.1          0.4               20            5         5
# 44  GCA_001097865.1          0.4               20            5         5
# 45  GCA_001760805.1          0.4               20            5         5
# 46  GCA_000813025.1          0.4               20            5         5
# 47  GCA_902159345.1          0.4               20            5         5
# 48  GCA_006381655.1          0.4               20            5         5
# 49  GCA_003942485.1          0.4               20            5         5
#
#     nr_tool  nr_toolscheme  nr_scheme avge_dispersion  coverage_denominator  \
# 0         0              0          0            None                     0
# 1         7              2          6             1.0                    28
# 2         0              0          1            None                     0
# 3         5              0          9             NaN                     0
# 4         0              0          3            None                     0
# 5         0              0          0            None                     0
# 6         0              0          6            None                     0
# 7         1              1          3             1.0                    10
# 8         0              0         12            None                     0
# 9         0              0          0            None                     0
# 10        0              0          1            None                     0
# 11        0              0          1            None                     0
# 12        0              0          4            None                     0
# 13        1              1          2             1.0                    10
# 14       12              2          5             1.0                    34
# 15        0              0          5            None                     0
# 16        0              0          5            None                     0
# 17        3              2         10             1.0                    20
# 18        0              0          3            None                     0
# 19        0              0          1            None                     0
# 20        0              0          2            None                     0
# 21        0              0          2            None                     0
# 22        0              0          1            None                     0
# 23        0              0          5            None                     0
# 24        1              1          2             1.0                    11
# 25        0              0          0            None                     0
# 26        0              0          0            None                     0
# 27        2              1          3             1.0                     9
# 28        0              0          0            None                     0
# 29        0              0          0            None                     0
# 30        0              0          3            None                     0
# 31        1              1          3             1.0                    10
# 32        0              0          4            None                     0
# 33        6              2          4             1.0                    22
# 34        3              1          2             1.0                     8
# 35        1              0          3             NaN                     0
# 36        0              0          4            None                     0
# 37        1              1          4             1.0                    15
# 38        2              1          6             1.0                     8
# 39        0              0          0            None                     0
# 40        3              1          5             1.0                     6
# 41        1              0          3             NaN                     0
# 42        0              0          0            None                     0
# 43        0              0          4            None                     0
# 44        2              2          2             1.0                    18
# 45        0              0          1            None                     0
# 46        0              0          0            None                     0
# 47        2              0          3             NaN                     0
# 48        1              0          3             NaN                     0
# 49        1              1          3             1.0                     7
#
#     coverage_numerator  dispersion_weighted
# 0                    0                  NaN
# 1                   18                  2.0
# 2                    0                  NaN
# 3                    0                  NaN
# 4                    0                  NaN
# 5                    0                  NaN
# 6                    0                  NaN
# 7                   10                  1.0
# 8                    0                  NaN
# 9                    0                  NaN
# 10                   0                  NaN
# 11                   0                  NaN
# 12                   0                  NaN
# 13                   7                  1.0
# 14                   9                  2.0
# 15                   0                  NaN
# 16                   0                  NaN
# 17                   3                  2.0
# 18                   0                  NaN
# 19                   0                  NaN
# 20                   0                  NaN
# 21                   0                  NaN
# 22                   0                  NaN
# 23                   0                  NaN
# 24                  11                  1.0
# 25                   0                  NaN
# 26                   0                  NaN
# 27                   6                  1.0
# 28                   0                  NaN
# 29                   0                  NaN
# 30                   0                  NaN
# 31                  10                  1.0
# 32                   0                  NaN
# 33                  20                  2.0
# 34                   7                  1.0
# 35                   0                  NaN
# 36                   0                  NaN
# 37                   7                  1.0
# 38                   1                  1.0
# 39                   0                  NaN
# 40                   3                  1.0
# 41                   0                  NaN
# 42                   0                  NaN
# 43                   0                  NaN
# 44                  18                  2.0
# 45                   0                  NaN
# 46                   0                  NaN
# 47                   0                  NaN
# 48                   0                  NaN
# 49                   6                  1.0

# %%
measures=conjscan.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 0.4               56             20        149                   216
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 0.4                         20.0                 136

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision    recall   F-score  dispersion  coverage
# 0          0.4   0.134228  0.357143  0.195122         1.0   0.62963

# %% [markdown]
# ## Phaster

# %%
phaster = pd.read_csv(input_path / "phaster_performance.csv")
phaster.columns=['genome', 'n_threshold', 'score_threshold', 'insize', 'dist', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
phaster['dispersion_weighted']=(phaster.nr_toolscheme)*(pd.to_numeric(phaster.avge_dispersion, errors='coerce'))

phaster
# Out:
#              genome  n_threshold  score_threshold  insize  dist  nr_tool  \
# 0   GCA_001868825.1          0.4               20       5     5        3
# 1   GCA_002017995.1          0.4               20       5     5       13
# 2   GCA_002092085.1          0.4               20       5     5        4
# 3   GCA_000504125.1          0.4               20       5     5        5
# 4   GCA_900116975.1          0.4               20       5     5        9
# 5   GCA_001073005.1          0.4               20       5     5        2
# 6   GCA_004361545.1          0.4               20       5     5        4
# 7   GCA_002077495.1          0.4               20       5     5        2
# 8   GCA_000309605.1          0.4               20       5     5        9
# 9   GCA_001649985.1          0.4               20       5     5        4
# 10  GCA_003796045.1          0.4               20       5     5        2
# 11  GCA_001815805.1          0.4               20       5     5        1
# 12  GCA_900992665.1          0.4               20       5     5        4
# 13  GCA_003963555.1          0.4               20       5     5        3
# 14  GCA_000441015.1          0.4               20       5     5        4
# 15  GCA_000232205.2          0.4               20       5     5        6
# 16  GCA_004055405.1          0.4               20       5     5        5
# 17  GCA_901544225.1          0.4               20       5     5        7
# 18  GCA_000465735.1          0.4               20       5     5        3
# 19  GCA_900490745.1          0.4               20       5     5        2
# 20  GCA_002532085.1          0.4               20       5     5        0
# 21  GCA_004334905.1          0.4               20       5     5        4
# 22  GCA_003606705.1          0.4               20       5     5        5
# 23  GCA_001304545.1          0.4               20       5     5        3
# 24  GCA_002083175.2          0.4               20       5     5        2
# 25  GCA_001578785.1          0.4               20       5     5        4
# 26  GCA_002897535.1          0.4               20       5     5        2
# 27  GCA_001334315.1          0.4               20       5     5        2
# 28  GCA_000522565.1          0.4               20       5     5        3
# 15                  74                  3.0
# 16                  80                  3.0
# 17                 182                  5.0
# 18                  69                  1.0
# 19                  27                  1.0
# 20                   0                  NaN
# 21                  69                  2.0
# 22                   0                  NaN
# 23                  65                  3.0
# 24                  54                  2.0
# 25                   0                  NaN
# 26                   0                  NaN
# 27                  62                  1.0
# 28                   0                  NaN
# 29                   0                  NaN
# 30                 131                  2.0
# 31                   0                  NaN
# 32                  99                  4.0
# 33                  67                  1.0
# 34                   0                  NaN
# 35                 101                  1.0
# 36                 181                  4.0
# 37                  69                  2.0
# 38                  52                  2.0
# 39                   0                  NaN
# 40                 136                  4.0
# 41                  46                  1.0
# 42                   0                  NaN
# 43                  92                  2.0
# 44                   0                  NaN
# 45                   0                  NaN
# 46                   0                  NaN
# 47                  98                  2.0
# 48                  26                  1.0
# 49                   0                  NaN

# %%
measures=phaster.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 0.4              168             80        149                  3428
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 0.4                         80.0                2959

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision   recall   F-score  dispersion  coverage
# 0          0.4   0.536913  0.47619  0.504732         1.0  0.863186

# %% [markdown]
# ## Joined for recall and precision

# %%
joined = pd.read_csv(input_path / "joined_performance.csv")
joined.columns=['genome', 'n_threshold', 'score_threshold', 'insize', 'dist', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
joined['dispersion_weighted']=(joined.nr_toolscheme)*(pd.to_numeric(joined.avge_dispersion, errors='coerce'))

joined
# Out:
#              genome  n_threshold  score_threshold  insize  dist  nr_tool  \
# 0   GCA_001868825.1          0.4               20       5     5        3
# 1   GCA_002017995.1          0.4               20       5     5       20
# 2   GCA_002092085.1          0.4               20       5     5        4
# 3   GCA_000504125.1          0.4               20       5     5       10
# 4   GCA_900116975.1          0.4               20       5     5        9
# 5   GCA_001073005.1          0.4               20       5     5        2
# 6   GCA_004361545.1          0.4               20       5     5        4
# 7   GCA_002077495.1          0.4               20       5     5        3
# 8   GCA_000309605.1          0.4               20       5     5        9
# 9   GCA_001649985.1          0.4               20       5     5        4
# 10  GCA_003796045.1          0.4               20       5     5        2
# 11  GCA_001815805.1          0.4               20       5     5        1
# 12  GCA_900992665.1          0.4               20       5     5        4
# 13  GCA_003963555.1          0.4               20       5     5        4
# 14  GCA_000441015.1          0.4               20       5     5       15
# 15  GCA_000232205.2          0.4               20       5     5        6
# 40              5          5             1.0                   158
# 41              1          3             1.0                    51
# 42              0          0            None                     0
# 43              2          4             1.0                   107
# 44              2          2             1.0                    18
# 45              0          1             NaN                     0
# 46              0          0            None                     0
# 47              2          3             1.0                    98
# 48              1          3             1.0                    57
# 49              1          3             1.0                     7
#
#     coverage_numerator  dispersion_weighted
# 0                    0                  NaN
# 1                   54                  5.0
# 2                   46                  1.0
# 3                  168                  4.0
# 4                  134                  3.0
# 5                    0                  NaN
# 6                  162                  4.0
# 7                  110                  3.0
# 8                  174                  7.0
# 9                    0                  NaN
# 10                  51                  1.0
# 11                   0                  NaN
# 12                 136                  3.0
# 13                  53                  2.0
# 14                 132                  5.0
# 15                  74                  3.0
# 16                  80                  3.0
# 17                 185                  7.0
# 18                  69                  1.0
# 19                  27                  1.0
# 20                   0                  NaN
# 21                  69                  2.0
# 22                   0                  NaN
# 23                  65                  3.0
# 24                  60                  3.0
# 25                   0                  NaN
# 26                   0                  NaN
# 27                  68                  2.0
# 28                   0                  NaN
# 29                   0                  NaN
# 30                 131                  2.0
# 31                  10                  1.0
# 32                  99                  4.0
# 33                  87                  3.0
# 34                   7                  1.0
# 35                 101                  1.0
# 36                 181                  4.0
# 37                  76                  3.0
# 38                  53                  3.0
# 39                   0                  NaN
# 40                 139                  5.0
# 41                  46                  1.0
# 42                   0                  NaN
# 43                  92                  2.0
# 44                  18                  2.0
# 45                   0                  NaN
# 46                   0                  NaN
# 47                  98                  2.0
# 48                  26                  1.0
# 49                   6                  1.0

# %%
measures=joined.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 0.4              223             99        149                  3611
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 0.4                         99.0                3087

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision    recall   F-score  dispersion  coverage
# 0          0.4    0.66443  0.443946  0.532258         1.0  0.854888

# %% [markdown]
# # Benchmarking "sophisticated" approach

# %% [markdown]
# ## Preparation

# %%
project_path = Path().resolve().parent
input_path = project_path / "results" / "intermediate" / "benchmarking" / "intermediate" / "0.2 30 0.1 5"
#output_path = project_path / "results" / "MGE_files"

# %% [markdown]
# ## CONJscan

# %%
conjscan = pd.read_csv(input_path / "conjscan_performance.csv")
conjscan.columns=['genome', 'n_threshold', 'score_threshold', 'initialsize', 'distance', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
conjscan['dispersion_weighted']=(conjscan.nr_toolscheme)*(pd.to_numeric(conjscan.avge_dispersion, errors='coerce'))

conjscan
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/wm/45ntkynd66gd8wnsdr6vw7h40000gn/T/ipykernel_32888/1816185995.py in <module>
# ----> 1 conjscan = pd.read_csv(input_path / "conjscan_performance.csv")
#       2 conjscan.columns=['genome', 'n_threshold', 'score_threshold', 'initialsize', 'distance', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
#       3 conjscan['dispersion_weighted']=(conjscan.nr_toolscheme)*(pd.to_numeric(conjscan.avge_dispersion, errors='coerce'))
#       4
#       5 conjscan
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/lorevansantvliet/Desktop/Thesis/Project/results/intermediate/benchmarking/intermediate/0.2 30 0.1 5/conjscan_performance.csv'

# %%
measures=conjscan.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 0.2               56              6        113                    74
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 0.2                          6.0                  46

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision    recall   F-score  dispersion  coverage
# 0          0.2   0.053097  0.107143  0.071006         1.0  0.621622

# %% [markdown]
# ## Phaster

# %%
phaster = pd.read_csv(input_path / "phaster_performance.csv")
phaster.columns=['genome', 'n_threshold', 'score_threshold', 'insize', 'dist', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
phaster['dispersion_weighted']=(phaster.nr_toolscheme)*(pd.to_numeric(phaster.avge_dispersion, errors='coerce'))

phaster
# Out:
#              genome  n_threshold  score_threshold  insize  dist  nr_tool  \
# 0   GCA_001868825.1          0.2               30       5     5        3
# 1   GCA_002017995.1          0.2               30       5     5       13
# 2   GCA_002092085.1          0.2               30       5     5        4
# 3   GCA_000504125.1          0.2               30       5     5        5
# 4   GCA_900116975.1          0.2               30       5     5        9
# 5   GCA_001073005.1          0.2               30       5     5        2
# 6   GCA_004361545.1          0.2               30       5     5        4
# 7   GCA_002077495.1          0.2               30       5     5        2
# 8   GCA_000309605.1          0.2               30       5     5        9
# 9   GCA_001649985.1          0.2               30       5     5        4
# 10  GCA_003796045.1          0.2               30       5     5        2
# 11  GCA_001815805.1          0.2               30       5     5        1
# 12  GCA_900992665.1          0.2               30       5     5        4
# 13  GCA_003963555.1          0.2               30       5     5        3
# 14  GCA_000441015.1          0.2               30       5     5        0
# 15  GCA_000232205.2          0.2               30       5     5        6
# 16  GCA_004055405.1          0.2               30       5     5        5
# 17  GCA_901544225.1          0.2               30       5     5        7
# 18  GCA_000465735.1          0.2               30       5     5        3
# 47              0          3             NaN                     0
# 48              0          2             NaN                     0
# 49              0          1             NaN                     0
#
#     coverage_numerator  dispersion_weighted
# 0                    0                  NaN
# 1                    0                  NaN
# 2                    0                  NaN
# 3                  169                  4.0
# 4                    0                  NaN
# 5                    0                  NaN
# 6                   25                  1.0
# 7                    0                  NaN
# 8                    0                  NaN
# 9                    0                  NaN
# 10                   0                  NaN
# 11                   0                  NaN
# 12                   0                  NaN
# 13                  46                  1.0
# 14                   0                  NaN
# 15                   0                  NaN
# 16                  15                  1.0
# 17                  42                  3.0
# 18                   0                  NaN
# 19                   0                  NaN
# 20                   0                  NaN
# 21                   0                  NaN
# 22                   0                  NaN
# 23                   0                  NaN
# 24                  54                  2.0
# 25                   0                  NaN
# 26                   0                  NaN
# 27                   0                  NaN
# 28                   0                  NaN
# 29                   0                  NaN
# 30                   0                  NaN
# 31                   0                  NaN
# 32                   0                  NaN
# 33                   0                  NaN
# 34                   0                  NaN
# 35                 101                  1.0
# 36                   0                  NaN
# 37                  52                  1.0
# 38                   0                  NaN
# 39                   0                  NaN
# 40                   0                  NaN
# 41                   0                  NaN
# 42                   0                  NaN
# 43                   0                  NaN
# 44                   0                  NaN
# 45                   0                  NaN
# 46                   0                  NaN
# 47                   0                  NaN
# 48                   0                  NaN
# 49                   0                  NaN

# %%
measures=phaster.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 0.2              164             14        113                   678
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 0.2                         14.0                 504

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision    recall   F-score  dispersion  coverage
# 0          0.2   0.123894  0.085366  0.101083         1.0  0.743363

# %% [markdown]
# ## Joined for recall and precision

# %%
joined = pd.read_csv(input_path / "joined_performance.csv")
joined.columns=['genome', 'n_threshold', 'score_threshold', 'insize', 'dist', 'nr_tool', 'nr_toolscheme', 'nr_scheme', 'avge_dispersion', 'coverage_denominator', 'coverage_numerator']
joined['dispersion_weighted']=(joined.nr_toolscheme)*(pd.to_numeric(joined.avge_dispersion, errors='coerce'))

joined
# Out:
#              genome  n_threshold  score_threshold  insize  dist  nr_tool  \
# 0   GCA_001868825.1          0.2               30       5     5        3
# 1   GCA_002017995.1          0.2               30       5     5       20
# 2   GCA_002092085.1          0.2               30       5     5        4
# 3   GCA_900116975.1          0.2               30       5     5        9
# 21              0          3             NaN                     0
# 22              0          1             NaN                     0
# 23              3          2             1.0                    69
# 24              0          0            None                     0
# 25              0          0            None                     0
# 26              0          2             NaN                     0
# 27              0          0            None                     0
# 28              0          0            None                     0
# 29              0          3             NaN                     0
# 30              0          1             NaN                     0
# 31              0          2             NaN                     0
# 32              0          2             NaN                     0
# 33              0          2             NaN                     0
# 34              2          2             1.0                   122
# 35              0          4             NaN                     0
# 36              2          3             1.0                    68
# 37              0          2             NaN                     0
# 38              0          0            None                     0
# 39              0          4             NaN                     0
# 40              0          5             NaN                     0
# 41              0          0            None                     0
# 42              0          3             NaN                     0
# 43              0          0            None                     0
# 44              0          3             NaN                     0
# 45              0          1             NaN                     0
# 46              0          3             NaN                     0
# 47              0          2             NaN                     0
# 48              0          1             NaN                     0
#
#     coverage_numerator  dispersion_weighted
# 0                    0                  NaN
# 1                    0                  NaN
# 2                    0                  NaN
# 3                    0                  NaN
# 4                    0                  NaN
# 5                   25                  1.0
# 6                    0                  NaN
# 7                    0                  NaN
# 8                    0                  NaN
# 9                    0                  NaN
# 10                   0                  NaN
# 11                   0                  NaN
# 12                  52                  2.0
# 13                   0                  NaN
# 14                   0                  NaN
# 15                  15                  1.0
# 16                  53                  5.0
# 17                   0                  NaN
# 18                   0                  NaN
# 19                   0                  NaN
# 20                   0                  NaN
# 21                   0                  NaN
# 22                   0                  NaN
# 23                  60                  3.0
# 24                   0                  NaN
# 25                   0                  NaN
# 26                   0                  NaN
# 27                   0                  NaN
# 28                   0                  NaN
# 29                   0                  NaN
# 30                   0                  NaN
# 31                   0                  NaN
# 32                   0                  NaN
# 33                   0                  NaN
# 34                 111                  2.0
# 35                   0                  NaN
# 36                  60                  2.0
# 37                   0                  NaN
# 38                   0                  NaN
# 39                   0                  NaN
# 40                   0                  NaN
# 41                   0                  NaN
# 42                   0                  NaN
# 43                   0                  NaN
# 44                   0                  NaN
# 45                   0                  NaN
# 46                   0                  NaN
# 47                   0                  NaN
# 48                   0                  NaN

# %%
measures=joined.groupby(by=['n_threshold'], axis=0).sum()
measures=measures.loc[:, ['nr_tool', 'nr_toolscheme', 'nr_scheme', 'coverage_denominator', 'dispersion_weighted', 'coverage_numerator']]
measures
# Out:
#              nr_tool  nr_toolscheme  nr_scheme  coverage_denominator  \
# n_threshold
# 0.2              198             16        107                   561
#
#              dispersion_weighted  coverage_numerator
# n_threshold
# 0.2                         16.0                 376

# %%
measures['precision']=measures.nr_toolscheme/measures.nr_scheme
measures['recall']=measures.nr_toolscheme/measures.nr_tool
measures['coverage']=measures.coverage_numerator/measures.coverage_denominator
measures['dispersion']=measures.dispersion_weighted/measures.nr_toolscheme
measures['F-score']=2*measures.precision*measures.recall/(measures.precision+measures.recall)
m = measures.loc[:,['precision', 'recall', 'F-score', 'dispersion', 'coverage']]
m = m.reset_index()
m
# Out:
#    n_threshold  precision    recall   F-score  dispersion  coverage
# 0          0.2   0.149533  0.080808  0.104918         1.0  0.670232
